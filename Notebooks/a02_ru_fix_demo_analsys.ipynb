# %%
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path
from typing import List, Tuple
from collections import defaultdict
from sklearn.model_selection import StratifiedKFold, train_test_split

# %%
ru_fix_demo = pd.read_csv("../Datasets/Fix_Demo_Ru.csv", )

# %%
ru_fix_demo.head()
# Out:
#    Text_ID  Fix_X  Fix_Y  Fix_Duration  Word_Number    Word  \
# 0        1   79.0  104.0         221.0            1  Samuel
# 1        1  118.0  101.0         289.0            1  Samuel
# 2        1  247.0   92.0         337.0            2  Morse,
# 3        1  336.0  118.0         281.0            3    best
# 4        1  416.0  125.0         250.0            4   known
#
#                Sentence Language SubjectID  L2_spelling_skill  \
# 0  Samuel Morse, best k       ru     rum_1           4.431818
# 1  Samuel Morse, best k       ru     rum_1           4.431818
# 2  Samuel Morse, best k       ru     rum_1           4.431818
# 3  Samuel Morse, best k       ru     rum_1           4.431818
# 4  Samuel Morse, best k       ru     rum_1           4.431818
#
#    L2_vocabulary_size  vocab.t2.5  L2_lexical_skill  TOWRE_word  \
# 0                3.55         4.5            4.0625    3.798077
# 1                3.55         4.5            4.0625    3.798077
# ...

# %%
target = ["Target"]

features = [
    'Text_ID', 'Fix_X', 'Fix_Y', 'Fix_Duration', 'Word_Number', 'Word',
    'Sentence', 'Language', 'SubjectID', 'L2_spelling_skill',
    'L2_vocabulary_size', 'vocab.t2.5', 'L2_lexical_skill', 'TOWRE_word',
    'TOWRE_nonword', 'motiv', 'IQ', 'Age', 'Sex'
]

# %%
ru_fix_demo.columns
# Out:
# Index(['Text_ID', 'Fix_X', 'Fix_Y', 'Fix_Duration', 'Word_Number', 'Word',
#        'Sentence', 'Language', 'SubjectID', 'L2_spelling_skill',
#        'L2_vocabulary_size', 'vocab.t2.5', 'L2_lexical_skill', 'TOWRE_word',
#        'TOWRE_nonword', 'motiv', 'IQ', 'Target', 'Age', 'Sex'],
#       dtype='object')
